# %%
variable
it is a name of storage space which is used to store data.
Its value maybe changes.
It always contains last value stored to it.
Variable is created by assigning a value to it.
 Unlike some languages, Python does not require you to declare the variable type — it’s determined automatically when you 
assign a value.

# %%
Dynamic Typing – You can assign any type of value to a variable without specifying its type.
No Explicit Declaration – Variables are created when you first assign a value

name="tom"
rollno=5

here rollno and name are the name of variables.
value of name is tom, rollno is 5

Printing value of variable
we can print value of a variable using print() function.

# %%
#creating variable
name="tom"
rollno=5
per = 89.76
presenty = True
x = 5+9j
#printing value of variable
print("name is:",name)
print("roll number is:",rollno)
print("per is:",per)
print("present or not: ",presenty)
print("complex no is:",x)

print(type(name))
print(type(rollno))
print(type(per))
print(type(presenty))
print(type(x))
# Out:
# name is: tom
# roll number is: 5
# per is: 89.76
# present or not:  True
# complex no is: (5+9j)
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'complex'>

# %%
Rules to define a variable
The first letter of a variable should be alphabet or underscore(_)
The first letter of a variable should not be digit.
After first character it may be combination of alphabets and digits.
Blank space are not allowed in variable name.
variable name should not be keyword.
Variable names are case sensitive. for eg. marks and MARKS are
  different variables.
