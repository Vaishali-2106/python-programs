# %%
Object
Object is having states and behaviours in which state means what does it has and behaviour means what does it do. 
for eg. a pen has states:ink,nib,needle,cap etc.
        Behaviors:writing.
            
         *object is an instance of a class.
         *object comprises both  data members and methods.
         *Object is created from a class.
        
Class
*It is a collection of data members and member functions.
*Data members are the variable used inside class.
*Member functions are the function or method used inside class.
*It is also called userdefined data type.
*class keyword is used to create class.

# %%
Python Classes/Objects
Python is an object oriented programming language.
Almost everything in Python is an object, with its properties and methods.

# %%
class person:
    name="abc"
    age=34
    email="abc@gmail.com"  # member of cls / data member
    
# creating object of cls person
p1 = person()
print("name is: ",p1.name)
print("age is: ",p1.age)
print("email is: ",p1.email)

p2 = person()
print("name is: ",p2.name)
print("age is: ",p2.age)
print("email is: ",p2.email)

# %%
class Person:

    def person(self):   # method / member fun
        print("enter name, age, rollno")
        name=input("enter name")
        age=input("enter age")
        email=input("enter email")
        print("name is: ",name,"\n age is: ",age,"\n email is: ",email)
        
p = Person()        
p.person()

p2 = Person()
p2.person()
# Out:
# enter name, age, rollno
# enter name ram
# enter age 23
# enter email ram@gmail.com
# name is:  ram
#  age is:  23
#  email is:  ram@gmail.com
# enter name, age, rollno
# enter name shyam
# enter age 22
# enter email shyam@gmail.com
# name is:  shyam
#  age is:  22
#  email is:  shyam@gmail.com

# %%
class Person:
#instance member
    def input(self):   # method / member fun
        print("enter name, age, rollno")
        self.name=input("enter name")   # local var input()
        self.age=input("enter age")
        self.email=input("enter email")
    def display(self)     :
        print("name is: ",self.name,"\n age is: ",self.age,"\n email is: ",self.email)

        
p = Person()        
p.input()
p.display()
print(p.name)    # accessing cls member through object
# Out:
# enter name, age, rollno
# enter nameabcd
# enter age34
# enter emailasas
# name is:  abcd
#  age is:  34
#  email is:  asas
# abcd

# %%
class Person:
    def person(self):   # method / member fun
        print("enter name, age, rollno")
        self.name=input("enter name")
        self.age=input("enter age")
        self.email=input("enter email")
    def display(self)    :
        print("name is: ",self.name,"\n age is: ",self.age,"\n email is: ",self.email)

   
     
p = Person()        
p.person()

p2 = Person()
p2.person()

p.display()
p2.display()

# %%
#creating class
class student:
    #defining class variables
    name="Rocky"
    roll=5
#here student is class and name and roll are variables.

# %%
class MyClass:
    x = 5

print(MyClass)
# Out:
# <class '__main__.MyClass'>

# %%
Create Object of class
we can create object of class by using class name.
There is no need of new keyword like java in python to create 
object.
Syntax:
    obj_name=class_name()
    
Now we can use the class named MyClass to create objects:
    for eg. 
    s1=student()

# %%
class stud:
    rollno=5
    name="abcd"
    
obj=stud()    
print(obj.rollno)
print(obj.name)

obj2=stud()
print(obj2.rollno)
print(obj2.name)

# %%
class Person:
    rollno=5
    name="shiv"
    def info(self):
        print("per rollno : ",self.rollno)
        print("per name : ",self.name)
        
p = Person()        
p.info()
# Out:
# per rollno :  5
# per name :  shiv

# %%
class Person:
  
    def info(self):
        rollno=9
        name="ram"
        print("per rollno : ",rollno)
        print("per name : ",name)
        
p = Person()        
p.info()

# %%
class stud:
    rollno=int(input("enter ron"))
    name=input("enter name")
    
obj=stud()    
print(obj.rollno)
print(obj.name)

obj2=stud()
print(obj2.rollno)
print(obj2.name)

# %%
Accessing variables of class
We can access the variables of class by using dot(.) operator
with object.
We can also access function of a class by using dot(.) operator

# %%
#creating class
class student:
#defining class variables
    name="xyz"
    roll=5
    
    #creating object
s1=student()    
s2=student()
#accessing class variable
print("name:",s1.name)
print("roll no:",s1.roll)
print("name:",s2.name)
print("roll no:",s2.roll)

print(id(s1))
print(id(s2))
 #The id() function returns a unique id for the specified object. All objects in Python has its own 
 # unique id. The id is assigned to the object when it is created. The id is the object's memory 
#  address, and will be different for each time you run the program.

# %%
class emp:
    id=5
    name="abc"
    def emp_fun(self):
        print("hello world")
        print("emp id is: ",self.id)  #instance variable 
        print("emp name is: ",self.name)
    
    
obj=emp()  #creating an object 
obj.emp_fun()

# %%
class Sample:
    x=2  # x is class variable
    def get(self,y): # y is instance variable
        self.y=y
s1=Sample()
s1.get(3)             # Access attributes
print(s1.x," ",s1.y)
s2=Sample()
s2.y=4                # modify attributes
print(s2.x," ",s2.y)
# Out:
# 2   3
# 2   4

# %%
class c1:
    a = 5  # instance member of cls  
    def fun(self):   #instance method 
        y = 10  #local var of fun
        self.y = y
        print("value of a is: ",self.a)
        print("value of y is: ",y)
    
obj = c1()     # instance of cls  
print(obj.a)
obj.fun()
print(obj.y)
# Out:
# 5
# value of a is:  5
# value of y is:  10
# 10

# %%
class c1:
    a = 5  # instance member of cls  
    y = 12
    def fun(self,y):   #instance method
        self.y = y
        print("value of a is: ",self.a)
        print("value of y is: ",y)
    
obj = c1()     # instance of cls  
print(obj.a)
print(obj.y)
obj.fun(45)
print(obj.y)
obj2 = c1()
obj2.y=100
print(obj2.y)
# Out:
# 5
# 12
# value of a is:  5
# value of y is:  45
# 45
# 100
# 45

# %%
class Sample:
    x=2  # x is class variable
    def get(self,y): # here y is local variable
        self.y=y     # assign to instance y
    def show(self)    :
        #print(self.y)
        return self.y
        
s1 = Sample()   
s1.get(10)
print(s1.show())

# %%
class emp:
    id=5
    name="abc"
    
obj=emp()   
print("id is: ",obj.id)
print("name is: ",obj.name)

# %%
class emp:
    id=5
    name="abc"
    def myfun(self):
        print("id is: ",self.id)
        print("name is: ",self.name)
obj=emp()
obj.myfun()
obj2 = emp()
obj2.myfun()

# %%
class emp:
    def getdata(self):
        self.name=input("enter name")
        self.age=int(input("enter age"))
    def putdata(self):
        print("name is: ",self.name)
        print("age is: ",self.age)
        
e1 = emp()        
e1.getdata()
e1.putdata()
# Out:
# enter nameret
# enter age33334
# name is:  ret
# age is:  33334

# %%
class oper:
    def add(self):
        a=int(input("enter a"))
        b=int(input("enter b"))
        ad=a+b
        print("add is: ",ad)
        
o=oper()        
o.add()

# %%
class oper:
    def add(self,a,b):
        ad=a+b
        print("add is: ",ad)
        
o=oper()   
a=int(input("enter a"))
b=int(input("enter b"))
o.add(a,b)

# %%
class student:
    rollno=5
    name="abc"
    def fun1(self,per):
        print(self.rollno)
        print(self.name)
        print(per)
       
obj=student()   
obj.fun1(45)
# Out:
# 5
# abc
# 45

# %%
class student:
    rollno=5
    def fun1(self,name):
        print("roll no is: ",self.rollno)
        print("student name is: ",name) 
        
obj=student()        
obj.fun1("abc")
# Out:
# roll no is:  5
# student name is:  abc

# %%
class student:
    def fun1(self,no):
         print("square of no is: ",no*no)
        
obj=student()        
obj.fun1(4)
# Out:
# square of no is:  16

# %%
class arith:
    def add(self, a,b):
        self.a=a
        self.b=b
        return a+b
    def sub(self):
        s=self.a-self.b
        return s
    
a = arith() 

print("add is: ",a.add(10,5))
print("sub is: ",a.sub())

# %%
class emp:
    def input(self,name,roll):
        self.sname=name
        self.sroll=roll
    
    def display(self):
        print("name is: ",self.sname)
        print("rollno is: ",self.sroll)     
        
obj=emp()    
obj.input("vaishali",5)
obj.display()

# %%
class emp:
    name="abc"
    id=2
    def emp_fun(self):
        print("emp name is: ",self.name)
        print("emp id is: ",self.id)
obj=emp()    

obj.emp_fun()

# %%
#class with variable and function
#creating class
class student:
#defining class variables
    roll=int(input("enter roll no"))
    name=input("enter name")
    marks=float(input("enter marks"))
    #defining function
    def showinfo(self):
        print("name:",self.name)
        print("roll no:",self.roll)
        print("marks:",self.marks)
    
    #creating object
s1=student()    
#calling function of class
s1.showinfo()
# Out:
# enter roll no 3
# enter name vaishali
# enter marks 56
# name: vaishali
# roll no: 3
# marks: 56.0

# %%
here to access a class variables inside function self keyword is
used because self refers to the current class object.

# %%
class abc:
    
    def info(self, rollno, name):
        self.per=78.89
        print("rollno is: ",rollno)
        print("name is: ",name)
        print("per is: ",self.per)
        
        
a=abc()        
a.info(5,"ram")
a.per=98.88
print(a.per)
#print(id(a.info(4,"sdf")))

# %%
#getter and setter
class rect:
 
    def area(self,lngth, bre):
        # setter
        self.leng=lngth
        self.bre=bre
        arear=self.leng*self.bre
        print("area of rect is: ",arear)
        
r=rect()        
r.area(5,6)
# Out:
# area of rect is:  30

# %%
constructor
it is a type of specila member fun , that executes when u create object of cls
means no need to calling

# %%
class JustCounter:
    __secretCount = 0
    
  
    def count(self):
        self.__secretCount += 1
        print(self.__secretCount)

counter = JustCounter()
counter.count()
counter.count()
#print(counter.__secretCount)   # shows an error because it is private
# Out:
# 1
# 2

# %%
class rect:
    leng=12
    bre=10
    # constructor no need calling
    # to initialize object of cls
    def __init__(self):
        # setter
        arear=self.leng*self.bre
        print("area of rect is: ",arear)
    def hi(self)     :
        print("something")
r=rect()        
r2=rect()
# Out:
# area of rect is:  120
# area of rect is:  120

# %%
Types of Methods:

Inside Python class 3 types of methods are allowed

⦁	Instance Methods
⦁	Class Methods
⦁	Static Methods

⦁	Instance Methods:

Inside method implementation if we are using instance variables then such type of methods are called instance methods.
Inside instance method declaration,we have to pass self variable.

def m1(self):

By using self variable inside method we can able to access instance variables.

Within the class we can call instance method by using self variable and from outside of the class we can call by using object reference.

# %%
🔹 Instance Method
Definition: A method that operates on an instance of the class.

Syntax: The first parameter is always self, which refers to the instance.

Access: Can access and modify instance variables and call other instance methods.

# %%
class MyClass:
    def __init__(self, value):
        self.value = value

    def instance_method(self):
        return f'Instance value: {self.value}'
    
obj = MyClass(10)
print(obj.instance_method())  # Output: Instance value: 10
# Out:
# Instance value: 10

# %%
class method

Definition: A method that operates on the class rather than instances.

Syntax: Uses the @classmethod decorator. First parameter is cls, which refers to the class.

Access: Can access and modify class variables, but not instance variables.

# %%
class MyClass:
    count = 0

    def __init__(self):
        MyClass.count += 1

    @classmethod
    def get_count(cls):
        return f'Number of instances: {cls.count}'
    
a = MyClass()
b = MyClass()

print(MyClass.get_count())
# Out:
# Number of instances: 2

# %%
class Animal:
    legs=4
    # static var
    @classmethod # decorator
    def walk(cls,name):

        print('{} walks with {} legs...'.format(name,cls.legs))
        
Animal.walk('Dog')
Animal.walk('Cat')
# Out:
# Dog walks with 4 legs...
# Cat walks with 4 legs...

# %%
class Student:
    student_id = 'V10'
    student_name = 'Ram '
    @classmethod  # this is class method using @clsmethod decorator
    def display(self):  # self is not recommend standard is cls
        print(self.student_id,self.student_name)
        print("Original attributes and their values of the Student class:")
Student.display()
# Out:
# V10 Ram
# Original attributes and their values of the Student class:

# %%
def show():
        roll=5
        name="sdf"
        print("stud roll no is: ",roll)
        print("stud name is: ",name)
         
print(id(show()))
# Out:
# stud roll no is:  5
# stud name is:  sdf
# 140719805811520

# %%
class std:
    def __init__(self):
        # fun overloading
        # body
        print("def constr invoked")
    def __init__(self, rollno, per)    :
        # diff body
        print("para constr ",rollno, per)
       
s2=std(4,78)

# %%
class Employee:
   # class attribute    
    empCount = 0
    def __init__(self, name, age):
        self.__name = name
        self.__age = age
        # modifying class attribute
        Employee.empCount += 1
        print ("Name:", self.__name, ", Age: ", self.__age)
        # accessing class attribute
        print ("Employee Count:", Employee.empCount)

e1 = Employee("Bhavana", 24)
print()
e2 = Employee("Rajesh", 26)
# Out:
# Name: Bhavana , Age:  24
# Employee Count: 1
#
# Name: Rajesh , Age:  26
# Employee Count: 2

# %%
# instance attribute class attribute

class Dog:
    # Class attribute Class attributes can be accessed by both class name and object name.
    species = "Canis familiaris"

    def __init__(self, name, age):
        # Instance attributes
        self.name = name  # instance attribute do not belong with cls name  	Instance attribute is accessed using the object name followed by dot notation.
        self.age = age
# Create instances
dog1 = Dog("Buddy", 3)
dog2 = Dog("Milo", 5)

# Access instance attributes
print(dog1.name)  # Output: Buddy
print(dog2.age)   # Output: 5

# Access class attribute
print(dog1.species)  # Output: Canis familiaris
print(dog2.species)  # Output: Canis familiaris

#print(Dog.name)
# Out:
# Buddy
# 5
# Canis familiaris
# Canis familiaris

# %%
class Employee:
    empCount = 0
    def __init__(self, name, age):
        self.name = name
        self.age = age
        Employee.empCount += 1   
    @classmethod
    def showcount(cls):
        print (cls.empCount)

    @classmethod
    def newemployee(cls, name, age):
        return name, age

e1 = Employee("Bhavana", 24)
e2 = Employee("Rajesh", 26)
e3 = Employee("John", 27)
#Employee.newemployee("Anil", 21)

#Employee.showcount()
e1.showcount()
print(Employee.newemployee("Anil", 21))
# Out:
# 3
# ('Anil', 21)

# %%
class Cloth:
    pass

# Define the class method outside
@classmethod
def brandName(cls):
    print("Name of the brand is Raymond")

# Add method dynamically
setattr(Cloth, "brandName", brandName)

# Call the method
Cloth.brandName()
