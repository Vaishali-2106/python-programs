# %%
#Change List Items
Change Item Value
To change the value of a specific item, refer to the index number:

# %%
#Change the second item:
thislist = ["apple", "banana", "cherry"]
thislist[0] = "MANGO"
print(thislist)
# Out:
# ['MANGO', 'banana', 'cherry']

# %%
#Change a Range of Item Values
thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[2:4] = ["blackcurrant"]
print(thislist)
# Out:
# ['apple', 'banana', 'blackcurrant', 'kiwi', 'mango']

# %%
thislist = ["apple", "banana", "cherry"]
thislist[1:2] = ["blackcurrant",  "watermelon"]
print(thislist)
# Out:
# ['apple', 'blackcurrant', 'watermelon', 'cherry']

# %%
#Change the second and third value by replacing it with one value:
thislist = ["apple", "banana", "cherry"]
thislist[0:3] = ["watermelon","mango"]
print(thislist)
# Out:
# ['watermelon', 'mango']

# %%
#Insert Items
To insert a new list item, without replacing any of the existing values, 
we can use the insert() method.
The insert() method inserts an item at the specified index:

# %%
thislist = ["apple", "banana", "cherry"]

thislist.insert(1,"watermelon")
print(thislist)
# Out:
# ['apple', 'watermelon', 'banana', 'cherry']

# %%
#Python - Add List Items
#Append Items

# %%
#Using the append() method to append an item:
thislist = ["apple", "banana", "cherry"]
thislist.append("orange")
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'orange']

# %%
thislist = ["apple", "banana", "cherry"]
thislist.insert(0, "orange")
print(thislist)
# Out:
# ['orange', 'apple', 'banana', 'cherry']

# %%
#Extend List
#Add the elements of tropical to thislist:
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']

# %%
#Remove List Items
Remove Specified Item

The remove() method removes the specified item.

# %%
thislist = ["apple", "banana", "cherry"]
thislist.remove("apple")
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
#Remove the second item:

thislist = ["apple", "banana", "cherry"]
thislist.pop(1)
print(thislist)
# Out:
# ['apple', 'cherry']

# %%
#Remove the last item:

thislist = ["apple", "banana", "cherry"]
thislist.pop()
print(thislist)
# Out:
# ['apple', 'banana']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist[0]
print(thislist)
# Out:
# ['banana', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
del thislist
#print(thislist)

# %%
thislist = ["apple", "banana", "cherry"]
thislist.clear()
print(thislist)
# Out:
# []

# %%
#Sort List Alphanumerically
List objects have a  sort() 
method that will sort the list alphanumerically, ascending, by default:

# %%
thislist = ["orange", "mango", "kiwi",  "pineapple", "banana"]
thislist.sort()
print(thislist)
# Out:
# ['banana', 'kiwi', 'mango', 'orange', 'pineapple']

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort()
print(thislist)
# Out:
# [23, 50, 65, 82, 100]

# %%
#Sort Descending
To sort descending, use the keyword argument reverse = True:

# %%
thislist = ["orange", "mango", "kiwi",  "pineapple", "banana"]
thislist.sort(reverse = True)
print(thislist)
# Out:
# ['pineapple', 'orange', 'mango', 'kiwi', 'banana']

# %%
thislist = [100, 50, 65, 82, 23]
thislist.sort(reverse = True)
print(thislist)
# Out:
# [100, 82, 65, 50, 23]

# %%
#Reverse Order
The reverse() method reverses the current sorting order of the elements

# %%
thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.reverse()
print(thislist)
# Out:
# ['cherry', 'Kiwi', 'Orange', 'banana']

# %%
#Copy a List
#Make a copy of a list with the copy() method:

# %%
thislist = ["apple", "banana", "cherry"]
mylist  = thislist.copy()
print(mylist)
print(thislist)
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']

# %%
values = []
while True:
    value = input("Enter a value (or type 'done' to finish): ")
    if value.lower() == 'done':
        break
    values.append(value)

print("You entered:", values)
# Out:
# Enter a value (or type 'done' to finish):  1
# Enter a value (or type 'done' to finish):  2
# Enter a value (or type 'done' to finish):  3
# Enter a value (or type 'done' to finish):  4
# Enter a value (or type 'done' to finish):  5
# Enter a value (or type 'done' to finish):  done
# You entered: ['1', '2', '3', '4', '5']

# %%
num = int(input("How many values do you want to enter? "))
values = []

for i in range(num):   # i = 1
    value = input(f"Enter value #{i+1}: ")   #formatted string literal
    values.append(value)

print("Your values are:", values)
# Out:
# How many values do you want to enter?  4
# Enter value #1:  10
# Enter value #2:  20
# Enter value #3:  30
# Enter value #4:  40
# Your values are: ['10', '20', '30', '40']

# %%
name = "Alice"
age = 30

print(f"name is:  {name} \n age is: {age}")
# Out:
# name is:  Alice
#  age is: 30

# %%
x = 10
y = 20
print(f"{x} + {y} = {x + y}")  # Output: 10 + 20 = 30
# Out:
# 10 + 20 = 30

# %%
rollno=5
print(f"stud rollno is: {rollno}")
# Out:
# stud rollno is: 5

# %%
numbers = [10, 20, 30, 40]
total = sum(numbers)
print("Sum of list elements:", total)

numbers = [1, 2, 3, 4, 5]
total = 0
for num in numbers:
    total += num
print("Total:", total)
# Out:
# Sum of list elements: 100
# Total: 15

# %%
numbers = [1, 2, 3, 4, 5, 6]
even_sum = 0

for num in numbers:
    if num % 2 == 0:
        even_sum += num

print("Sum of even numbers:", even_sum)
# Out:
# Sum of even numbers: 12

# %%
nums = [1, 3, 5, 3, 3, 7, 9]
target = 5
count1 = 0

for num in nums:
    if num == target:
        count1 += 1

print(f"{target} appears {count1} times in the list.")
# Out:
# 5 appears 1 times in the list.

# %%
nums = [1, 3, 5, 3, 3, 7, 9]
target = 3
count = nums.count(target)

print(f"{target} appears {count} times in the list.")
# Out:
# 3 appears 3 times in the list.
