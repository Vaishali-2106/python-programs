# %%
#Python If ... Else
#Python Conditions and If statements
•Equals: a == b
•Not Equals: a != b
•Less than: a < b
•Less than or equal to: a <= b
•Greater than: a > b
•Greater than or equal to: a >= b

# %%
# SIMPLE if Statement
#An "if statement" is written by using the if keyword.
#If exicute if condition related true part

# %%
# a=int(input("enter a"))
# b=int(input("enter b"))
a = 10
b = 5
if a>b:
    print("%d is greater than %d"%(a,b))
# Out:
# 10 is greater than 5

# %%
mks = 70
if mks>=35:
    print("studis pass mks is:  %d"%(mks))
# Out:
# studis pass mks is:  70

# %%
name="ram"
rno=5
per=78.89
#print("stud name is: %s, \n stud rno is: %d, \n per is: %.2f"%(name,rno,per))   using format specifier like %d %s
print(f'name is: {name} \n rollno is: {rno} \n per is: {per}') # formatted string literals
# Out:
# name is: ram
#  rollno is: 5
#  per is: 78.89

# %%
no1=int(input("enter num a"))
no2=int(input("enter num b"))

if no1<no2:
    print("%d is less than %d"%(no1,no2))
else:
    print("a is grather than b")

# %%
x=10

if x==10:
    print("%d is equal to 10" % x)
else:
    print("x is not equal to 10")

# %%
no = int(input("enter the number?"))  
#no = 9
if no%2==0:
    print("%d is even no"%no)
else:
    print(no," is odd no")
# Out:
# enter the number? 99
# 99  is odd no

# %%
#One line if else statement:

a = 10
b = 30
print("A") if a > b else print("print another")
# Out:
# print another

# %%
age = 34
status = "Adult" if age >= 18 else "Minor"
print(status)
# Out:
# Adult

# %%
number = 9
parity = "Even" if number % 2 == 0 else "Odd"
print(parity)
# Out:
# Odd

# %%
#Short Hand If
#If you have only one statement to execute, 
#you can put it on the same line as the if statement.

# %%
#One line if else statement:
a = 27
b = 3
print("A") if a > b else print("B")
# Out:
# A

# %%
#One line if else statement, with 3 conditions:
a = 40
b = 90
print("A") if a > b else print("=") if a == b else print("B")
# Out:
# B

# %%
a = 90
b = 40
print("a is largest no") if a>b  else print("b is equal to a")  if  b==a else print("b is greater")
# Out:
# a is largest no

# %%
a=80
b=100
print("hello")if a>b else print("both")if a==b else print("hello python")

# %%
And

The and keyword is a logical operator, and is used to combine
conditional statements:

# %%
#Test if a is greater than b, AND if c is greater than a
a =500
b = 50
c = 100
if a > b or c > a:
    print("either one conditions are True")    
else:
    print("one cond is false")

# %%
a=10
b=2
c=5
if a>b and c<a:
    print("both are true")

# %%
Or
The or keyword is a logical operator, and is used to 
combine conditional statements:

# %%
a = 200
b = 33
c = 300
if a > b or c > a:
     print("Either one condition is True")

# %%
#Elif
#The elif keyword is 
#pythons way of saying "if the previous conditions were not true, 
#then try this condition".

# %%
a=int(input("enter a"))
b=int(input("enter b"))
if a>b:
    print("%d is greater than %d"%(a,b))
elif a==b:
    print(" a is equal to b")
else:
    print("%d is greater than %d"%(b,a))
# Out:
# enter a 5
# enter b 5
#  a is equal to b

# %%
day=int(input("enter day of no"))
if day==1:
    print("monday")
elif day==2:
    print("Tuesday")
elif day==3:
    print("wed")
elif day==4:
    print("thursday")
elif day==5:
    print("fri")
elif day==6:
    print("sat")
elif day==7:
    print("sunday")
    
else:
    print("enter no bet 1 to 7")
# Out:
# enter day of no 3
# wed

# %%
a = int(input("Enter a? ")) 
b = int(input("Enter b? "))  
c = int(input("Enter c? "))  
if a>b and a>c:  
    print("a is largest") 
elif b>a and b>c:  
    print("b is largest")  
elif c>a and c>b:  
    print("c is largest")  
else:
    print("all numbers are same")

# %%
number = int(input("Enter the number?"))  
if number==10:  
    print("number is equals to 10")  
elif number==50:  
    print("number is equal to 50");  
elif number==100:  
    print("number is equal to 100");  
else:  
    print("number is not equal to 10, 50 or 100");

# %%
marks = int(input("Enter the marks? "))  
if marks > 85 and marks <= 100:  
   print("Congrats ! you scored grade A ...")  
elif marks > 60 and marks <= 85:  
   print("You scored grade B + ...")  
elif marks > 40 and marks <= 60:  
   print("You scored grade B ...")  
elif (marks > 30 and marks <= 40):  
   print("You scored grade C ...")  
else:  
   print("Sorry you are fail ?")

# %%
Nested If

You can have if statements inside if statements,
this is called nested if statements.

# %%
a = 50
if a>10:
    print("a is above 10")
    if a==50:
        print("a is equal to 50")
    else:
        print("a is notequal to 50")
else:
    print("a is less than 10")
# Out:
# a is less than 10

# %%
age=int(input("enter age"))
if age>=18:
    print("age is greater than 18")
    if age<=40:
            print("eligible for job")
    else:
        print("but greater than 40")
else:
    print("age is less than 18")

# %%
no=50
if no<100:
    if no%2==0:
        print("no is even")
    else:
        print("no is odd")
else:
    print("sorry no is greater than 100")
 #find no odd or even but no should be positive

# %%
no=int(input("enter no"))

if no>0:
    print("wow no is pos")
    if no%2==0:
        print("congrats!  no is even")
        
    else:
        print("no is odd")
else:
    print("no is neg")
# Out:
# enter no-8
# no is neg

# %%
Ternary Operator:

Syntax:
x = firstValue if condition else secondValue

If condition is True then firstValue will be considered else secondValue will be considered.

# %%
a,b=10,20
x=30 if a<b else 40
print(x)   #30

# %%
#Eg 2: Read two numbers from the keyboard and print minimum value

a=int(input("Enter First Number:"))
b=int(input("Enter Second Number:"))
min=a if a<b else b
print("Minimum Value:",min)

# %%
#Note: Nesting of ternary operator is possible.

# Program for minimum of 3 numbers
a=int(input("Enter First Number:"))
b=int(input("Enter Second Number:"))
c=int(input("Enter Third Number:"))
min=a if a<b and a<c else b if b<c else c

print("Minimum Value:",min)

# %%
a=int(input("Enter First Number:"))
b=int(input("Enter Second Number:"))

print("Both numbers are equal" if a==b else "First Number is Less than Second Number" if
a<b else "First Number Greater than Second Number")
